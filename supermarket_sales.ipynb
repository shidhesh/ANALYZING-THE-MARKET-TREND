# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("supermarket_sales.csv")

# %%
df = data.copy() #copy original dataset in df

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.columns #to show all columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.info() #information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#for col in df:
#     print(col, df[col].unique())

# %%
df['Branch'].unique()  #find the unique value in branch column
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['Customer type']
# Out:
# 0      Member
# 1      Normal
# 2      Normal
# 3      Member
# 4      Normal
#         ...
# 995    Normal
# 996    Normal
# 997    Member
# 998    Normal
# 999    Member
# Name: Customer type, Length: 1000, dtype: object

# %%
col = df.columns  #access the all columns in dataframe

# %%
for col in df:
    print(col.replace(" ","_"))
# Out:
# Invoice_ID
# Branch
# City
# Customer_type
# Gender
# Product_line
# Unit_price
# Quantity
# Tax_5%
# Total
# Date
# Time
# Payment
# cogs
# gross_margin_percentage
# gross_income
# Rating

# %%
df.isna().sum()  #calcuate the na values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
non_numeric_cols = df.select_dtypes(include='object').columns  # extract the non numeric columns from dataset
print(non_numeric_cols)
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Date', 'Time', 'Payment'],
#       dtype='object')

# %%
dummy = df  # create a dummy dataframe

# %%
dummy['Tax 5%'] = dummy['Tax 5%'].apply(lambda x: round(x, 2))

# %%
dummy['Tax 5%']
# Out:
# 0      26.14
# 1       3.82
# 2      16.22
# 3      23.29
# 4      30.21
#        ...
# 995     2.02
# 996    48.69
# 997     1.59
# 998     3.29
# 999    30.92
# Name: Tax 5%, Length: 1000, dtype: float64

# %%
dummy['Total'] = dummy['Total'].apply(lambda x: round(x, 2)) #remove the last two digit that number number 12.3456 --> 12.34

# %%
dummy['gross margin percentage'] = dummy['gross margin percentage'].apply(lambda x: round(x, 2))

# %%
dummy['gross income'] = dummy['gross income'].apply(lambda x: round(x, 2))

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity  Tax 5%   Total       Date  \
# 0       Health and beauty       74.69         7   26.14  548.97   1/5/2019
# 1  Electronic accessories       15.28         5    3.82   80.22   3/8/2019
# 2      Home and lifestyle       46.33         7   16.22  340.53   3/3/2019
# 3       Health and beauty       58.22         8   23.29  489.05  1/27/2019
# 4       Sports and travel       86.31         7   30.21  634.38   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                     4.76         26.14     9.1
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379390   322.966840   307.58738
# std      26.494628     2.923431    11.708782   245.885362   234.17651
# min      10.080000     1.000000     0.510000    10.680000    10.17000
# 25%      32.875000     3.000000     5.927500   124.425000   118.49750
# 50%      55.230000     5.000000    12.090000   253.850000   241.76000
# 75%      77.935000     8.000000    22.445000   471.350000   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.760000e+00     15.379390     6.97270
# std               1.208527e-13     11.708782     1.71858
# min               4.760000e+00      0.510000     4.00000
# ...

# %%
df['City'].value_counts() #count the city elements
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df['date'] = pd.to_datetime(df['Date']) #convert Date into date  10/2/2019 --> 10-2-2019

# %%
df['Date']
# Out:
# 0       1/5/2019
# 1       3/8/2019
# 2       3/3/2019
# 3      1/27/2019
# 4       2/8/2019
#          ...
# 995    1/29/2019
# 996     3/2/2019
# 997     2/9/2019
# 998    2/22/2019
# 999    2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
df['date'].unique()
# Out:
# <DatetimeArray>
# ['2019-01-05 00:00:00', '2019-03-08 00:00:00', '2019-03-03 00:00:00',
#  '2019-01-27 00:00:00', '2019-02-08 00:00:00', '2019-03-25 00:00:00',
#  '2019-02-25 00:00:00', '2019-02-24 00:00:00', '2019-01-10 00:00:00',
#  '2019-02-20 00:00:00', '2019-02-06 00:00:00', '2019-03-09 00:00:00',
#  '2019-02-12 00:00:00', '2019-02-07 00:00:00', '2019-03-29 00:00:00',
#  '2019-01-15 00:00:00', '2019-03-11 00:00:00', '2019-01-01 00:00:00',
#  '2019-01-21 00:00:00', '2019-03-05 00:00:00', '2019-03-15 00:00:00',
#  '2019-02-17 00:00:00', '2019-03-02 00:00:00', '2019-03-22 00:00:00',
#  '2019-03-10 00:00:00', '2019-01-25 00:00:00', '2019-01-28 00:00:00',
#  '2019-01-07 00:00:00', '2019-03-23 00:00:00', '2019-01-17 00:00:00',
#  '2019-02-02 00:00:00', '2019-03-04 00:00:00', '2019-03-16 00:00:00',
#  '2019-02-27 00:00:00', '2019-02-10 00:00:00', '2019-03-19 00:00:00',
#  '2019-02-03 00:00:00', '2019-03-07 00:00:00', '2019-02-28 00:00:00',
# ...

# %%
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#type(df['date'])

# %%
#df['date'] = pd.to_datetime(df['date'])

# %%
#df['Date']

# %%
#df['day'] = (df['date']).dt.day
#df['month'] = (df['date']).dt.month
#df['year'] = (df['date']).dt.year

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# C:\Users\_Sidheshwar__\AppData\Local\Temp\ipykernel_7180\2145562215.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Hour'] = (df['Time']).dt.hour

# %%
df['Hour'].unique()
# Out:
# array([13, 10, 20, 18, 14, 11, 17, 16, 19, 15, 12])

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379390   322.966840
# min      10.080000     1.000000     0.510000    10.680000
# 25%      32.875000     3.000000     5.927500   124.425000
# 50%      55.230000     5.000000    12.090000   253.850000
# 75%      77.935000     8.000000    22.445000   471.350000
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708782   245.885362
#
#                              Time        cogs  gross margin percentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2024-01-08 15:24:41.880000   307.58738             4.760000e+00
# min           2024-01-08 10:00:00    10.17000             4.760000e+00
# 25%           2024-01-08 12:43:00   118.49750             4.760000e+00
# 50%           2024-01-08 15:19:00   241.76000             4.760000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %%
df.drop('Invoice ID' ,inplace = True, axis = 1 )  #drop non usable columns

# %%
df.drop('Date', inplace= True, axis= 1)

# %%
df.drop('Time', inplace= True, axis= 1)

# %%
df.drop('cogs', inplace= True, axis= 1)

# %%
df.drop('Payment', inplace= True, axis= 1)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total  gross margin percentage  \
# 0         74.69         7   26.14   548.97                     4.76
# ...

# %% [markdown]
# VISULIZATION

# %%
numerical_columns = ['Unit price', 'Quantity', 'Tax 5%', 'Total', 'gross income', 'Rating']

# Creating scatter plots for pairs of numerical columns
for i in range(len(numerical_columns)):
    for j in range(i + 1, len(numerical_columns)):
        plt.figure(figsize=(8, 6))
        plt.scatter(df[numerical_columns[i]], df[numerical_columns[j]])
        plt.xlabel(numerical_columns[i])
        plt.ylabel(numerical_columns[j])
        plt.title(f'Scatter plot: {numerical_columns[i]} vs {numerical_columns[j]}')
        plt.show()

# %%
plt.boxplot( x= df["Rating"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x="Branch", y = "Rating" ,data =df).set_title("Ratings by Branch")
# Out:
# Text(0.5, 1.0, 'Ratings by Branch')

# %%
sns.lineplot(x="Hour",  y = 'Quantity',data =df).set_title("Product Sales per Hour Based Date")
# Out:
# Text(0.5, 1.0, 'Product Sales per Hour Based Date')

# %%
sns.lineplot(x="Hour",  y ="date",data =df).set_title("Product Sales per Hour")
# Out:
# Text(0.5, 1.0, 'Product Sales per Hour')

# %%
sns.countplot(x="Quantity", hue = "Product line", data = df)
# Out:
# <Axes: xlabel='Quantity', ylabel='count'>

# %% [markdown]
# ## Product Line

# %%
sns.countplot(y="Product line", data = df).set_title("Payment Channel")
# Out:
# Text(0.5, 1.0, 'Payment Channel')

# %%
sns.countplot(y="Product line", hue = "Branch", data =df).set_title("Payment Channel by Branch")
# Out:
# Text(0.5, 1.0, 'Payment Channel by Branch')

# %%
sns.countplot(y="Product line", hue = "City", data =df).set_title("Payment Channel by City")
# Out:
# Text(0.5, 1.0, 'Payment Channel by City')

# %% [markdown]
# ## Customer Analysis

# %%
sns.countplot(x="Customer type", data =df).set_title("Customer Type")
# Out:
# Text(0.5, 1.0, 'Customer Type')

# %%
sns.countplot(x="Customer type", hue = "Branch", data = df).set_title("Customer Type by Branch")
# Out:
# Text(0.5, 1.0, 'Customer Type by Branch')

# %%
sns.countplot(x="Customer type", hue = "Gender", data = df).set_title("Customer Type by Gender")
# Out:
# Text(0.5, 1.0, 'Customer Type by Gender')

# %%
#x = df.drop('Gender', axis= 1)
#y = df['Gender']

# %%
#scaler = StandardScaler()
#x_scaled = scaler.fit_transform(x)

# %%
#pca = PCA(n_components=1)  # Specify the number of components to retain
#x_pca = pca.fit_transform(x_scaled)

# %%
#x_te, x_tr, y_te, y_tr = train_test_split(x, y, test_size= 0.75, random_state= 25 )

# %%
#svm = SVR(kernel='rbf')
#model = SVR(kernel='rbf')  # You can use any regression model here

# %%
#model.fit(x_tr, y_tr)

# %%
#y_pred = model.predict(x_te)
#y_pred***

# %%
#accuracy = r2_score(y_te, y_pred)
#print("R-squared after PCA:", accuracy)

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import train_test_split

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
label_encoder=LabelEncoder() #use LabelCoder for object column convert into int

# %%
df['Branch']=label_encoder.fit_transform(df['Branch'])

# %%
df['City']= label_encoder.fit_transform(df['City'])

# %%
df['Customer type'] = label_encoder.fit_transform(df['Customer type'])

# %%
df['Gender']= label_encoder.fit_transform(df['Gender'])

# %%
df['Product line']= label_encoder.fit_transform(df['Product line'])

# %%
df['date'] = label_encoder.fit_transform(df['date'])

# %%
df
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
num_col = df.select_dtypes(include='int').columns
flot_col = df.select_dtypes(include = 'float').columns

# %%
num_columns = list(num_col) + list(flot_col)

# %%
numerical_data = df[num_columns]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_data)

# %%
pca = PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
transformed_data = pca.transform(scaled_data)

# %%
transformed_data
# Out:
# array([[ 1.81191897,  1.72338859],
#        [-2.07095904, -0.77482546],
#        [ 0.08003364,  2.00504472],
#        ...,
#        [-2.71261869,  1.68142941],
#        [-2.04547595,  1.70977976],
#        [ 2.57285809,  1.63838105]])
